# %%
import pandas as pd
import matplotlib.pyplot as plt
from tqdm import tqdm

# %%
data = [pd.read_csv('train1.csv'), pd.read_csv('train2.csv',sep=";")]
result = pd.concat(data,ignore_index=True)

# %%
test=pd.read_csv('train1.csv')
test.head(10)
# Out:
#       countryName                           eprtrSectorName  \
# 0         Germany                          Mineral industry
# 1           Italy                          Mineral industry
# 2           Spain           Waste and wastewater management
# 3         Czechia                             Energy sector
# 4         Finland           Waste and wastewater management
# 5     Switzerland                             Energy sector
# 6          France                          Mineral industry
# 7          Poland  Paper and wood production and processing
# 8  United Kingdom                             Energy sector
# 9          France                         Chemical industry
#
#                         EPRTRAnnexIMainActivityLabel  \
# 0  Installations for the production of cement cli...
# 1  Installations for the production of cement cli...
# 2  Landfills (excluding landfills of inert waste ...
# 3  Thermal power stations and other combustion in...
# ...

# %%
print(test)
# Out:
#           countryName                           eprtrSectorName  \
# 0             Germany                          Mineral industry
# 1               Italy                          Mineral industry
# 2               Spain           Waste and wastewater management
# 3             Czechia                             Energy sector
# 4             Finland           Waste and wastewater management
# ...               ...                                       ...
# 18558         Finland                             Energy sector
# 18559           Spain  Paper and wood production and processing
# 18560          Sweden                             Energy sector
# 18561  United Kingdom                             Energy sector
# 18562         Germany       Production and processing of metals
#
#                             EPRTRAnnexIMainActivityLabel  \
# 0      Installations for the production of cement cli...
# 1      Installations for the production of cement cli...
# ...

# %%
#test2=pd.read_json()

# %%
test.columns
# Out:
# Index(['countryName', 'eprtrSectorName', 'EPRTRAnnexIMainActivityLabel',
#        'FacilityInspireID', 'facilityName', 'City', 'targetRelease',
#        'pollutant', 'reportingYear', 'MONTH', 'DAY', 'CONTINENT',
#        'max_wind_speed', 'avg_wind_speed', 'min_wind_speed', 'max_temp',
#        'avg_temp', 'min_temp', 'DAY WITH FOGS', 'REPORTER NAME', 'CITY ID'],
#       dtype='object')

# %%
def plot_alles(test):
    ind = 0
    for col in tqdm(test.columns):
        fig = plt.figure()
        plt.hist(test[col])
        #plt.tight_layout()
        plt.savefig(f"plots/plot-{col}.png")
        ind += 1
        plt.close(fig)

# %%
plt.hist(test["pollutant"])
plt.figure(figsize=(250,10))
plt.tight_layout()
